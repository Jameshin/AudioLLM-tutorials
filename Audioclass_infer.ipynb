# %%
from transformers import pipeline

model_id = "Eveready/distilhubert-finetuned-gtzan"
pipe = pipeline("audio-classification", model=model_id)

# %%
def classify_audio(filepath):
    preds = pipe(filepath)
    outputs = {}
    for p in preds:
        outputs[p["label"]] = p["score"]
    return outputs

# %%
import gradio as gr

demo = gr.Interface(
    fn=classify_audio, inputs=gr.Audio(type="filepath"), outputs=gr.outputs.Label()
)
demo.launch(debug=True)
# Out:
# /home/shandy77/.local/lib/python3.10/site-packages/gradio/outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# /home/shandy77/.local/lib/python3.10/site-packages/gradio/outputs.py:200: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   super().__init__(num_top_classes=num_top_classes, type=type, label=label)
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /home/shandy77/.local/lib/python3.10/site-packages/gradio/processing_utils.py:176: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 54, in ffmpeg_read
#     ffmpeg_process = subprocess.Popen(ffmpeg_command, stdin=subprocess.PIPE, stdout=subprocess.PIPE)
#   File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/routes.py", line 437, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1352, in process_api
#     result = await self.call_function(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1077, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#   File "/tmp/ipykernel_23596/1470810825.py", line 2, in classify_audio
#     preds = pipe(filepath)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 136, in __call__
#     return super().__call__(inputs, **kwargs)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1206, in __call__
#     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1212, in run_single
#     model_inputs = self.preprocess(inputs, **preprocess_params)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 158, in preprocess
#     inputs = ffmpeg_read(inputs, self.feature_extractor.sampling_rate)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 56, in ffmpeg_read
#     raise ValueError("ffmpeg was not found but is required to load audio files from filename")
# ValueError: ffmpeg was not found but is required to load audio files from filename
# /home/shandy77/.local/lib/python3.10/site-packages/gradio/processing_utils.py:176: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 54, in ffmpeg_read
#     ffmpeg_process = subprocess.Popen(ffmpeg_command, stdin=subprocess.PIPE, stdout=subprocess.PIPE)
#   File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/routes.py", line 437, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1352, in process_api
#     result = await self.call_function(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1077, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#   File "/tmp/ipykernel_23596/1470810825.py", line 2, in classify_audio
#     preds = pipe(filepath)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 136, in __call__
#     return super().__call__(inputs, **kwargs)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1206, in __call__
#     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1212, in run_single
#     model_inputs = self.preprocess(inputs, **preprocess_params)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 158, in preprocess
#     inputs = ffmpeg_read(inputs, self.feature_extractor.sampling_rate)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 56, in ffmpeg_read
#     raise ValueError("ffmpeg was not found but is required to load audio files from filename")
# ValueError: ffmpeg was not found but is required to load audio files from filename
# /home/shandy77/.local/lib/python3.10/site-packages/pydub/utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/processing_utils.py", line 133, in audio_from_file
#     audio = AudioSegment.from_file(filename)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/pydub/audio_segment.py", line 728, in from_file
#     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/pydub/utils.py", line 274, in mediainfo_json
#     res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#   File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ffprobe'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/routes.py", line 437, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1350, in process_api
#     inputs = self.preprocess_data(fn_index, inputs, state)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1200, in preprocess_data
#     processed_input.append(block.preprocess(inputs[i]))
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/components/audio.py", line 193, in preprocess
#     sample_rate, data = processing_utils.audio_from_file(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/processing_utils.py", line 143, in audio_from_file
#     raise RuntimeError(msg) from e
# RuntimeError: Cannot load audio from file: `ffprobe` not found. Please install `ffmpeg` in your system to use non-WAV audio file formats and make sure `ffprobe` is in your PATH.
# /home/shandy77/.local/lib/python3.10/site-packages/gradio/processing_utils.py:176: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 54, in ffmpeg_read
#     ffmpeg_process = subprocess.Popen(ffmpeg_command, stdin=subprocess.PIPE, stdout=subprocess.PIPE)
#   File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/routes.py", line 437, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1352, in process_api
#     result = await self.call_function(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1077, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#   File "/tmp/ipykernel_23596/1470810825.py", line 2, in classify_audio
#     preds = pipe(filepath)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 136, in __call__
#     return super().__call__(inputs, **kwargs)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1206, in __call__
#     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1212, in run_single
#     model_inputs = self.preprocess(inputs, **preprocess_params)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 158, in preprocess
#     inputs = ffmpeg_read(inputs, self.feature_extractor.sampling_rate)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 56, in ffmpeg_read
#     raise ValueError("ffmpeg was not found but is required to load audio files from filename")
# ValueError: ffmpeg was not found but is required to load audio files from filename
# /home/shandy77/.local/lib/python3.10/site-packages/gradio/processing_utils.py:176: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 54, in ffmpeg_read
#     ffmpeg_process = subprocess.Popen(ffmpeg_command, stdin=subprocess.PIPE, stdout=subprocess.PIPE)
#   File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/routes.py", line 437, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1352, in process_api
#     result = await self.call_function(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/gradio/blocks.py", line 1077, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#   File "/home/shandy77/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#   File "/tmp/ipykernel_23596/1470810825.py", line 2, in classify_audio
#     preds = pipe(filepath)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 136, in __call__
#     return super().__call__(inputs, **kwargs)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1206, in __call__
#     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1212, in run_single
#     model_inputs = self.preprocess(inputs, **preprocess_params)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 158, in preprocess
#     inputs = ffmpeg_read(inputs, self.feature_extractor.sampling_rate)
#   File "/home/shandy77/.local/lib/python3.10/site-packages/transformers/pipelines/audio_classification.py", line 56, in ffmpeg_read
#     raise ValueError("ffmpeg was not found but is required to load audio files from filename")
# ValueError: ffmpeg was not found but is required to load audio files from filename
